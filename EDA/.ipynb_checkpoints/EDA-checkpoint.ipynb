# %% [markdown]
# # Covid #

# %% [markdown]
# ### 1. Import relevant libraries & data###

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#import geopandas
# %matplotlib inline
import requests
import pandas as pd
import json
import ast

# %%
print(sns.__version__)

original_data = pd.read_csv("COVID-19_Case_Surveillance_Public_Use_Data_with_Geography.csv")
# Out:
# 0.11.2
# /Users/junghwankim/opt/anaconda3/envs/p1_covid/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
len(original_data)
# Out:
# 28652764

# %%
r = requests.get("https://data.cdc.gov/resource/n8mc-b4w4.json?$limit=50000&$offset=0&case_month=2021-08")
fox = r.json()
for i in fox:
    print(i['case_month'])
    print(i['res_state'])
#    print(i['state_fips_code'])
#    print(i['res_county'])
#    print(i['county_fips_code'])
    print(i['age_group'])
    print(i['sex'])
#    print(i['race'])
#    print(i['ethnicity'])
#    print(i['case_positive_specimen'])
#    print(i['process'])
#    print(i['exposure_yn'])
#    print(i['current_status'])
#    print(i['symptom_status'])
#    print(i['hosp_yn'])
    print(i['icu_yn'])
#    print(i['death_yn'])
    

    break
# Out:
# 2021-08
# OH
# 0 - 17 years
# NA
# Missing

# %%
date

# %%
total_cases = []

for k in range(50):
    
    slicing_data = "https://data.cdc.gov/resource/n8mc-b4w4.json?$limit=50000&$offset="
    page_info = 50000*k
    additional = "&case_month=2021-08"
    slicing_data = slicing_data+str(page_info)+additional

    r = requests.get(slicing_data)
    fox = r.json()
    
    if len(fox) > 0:
        for data in fox:
            current_case = []
            current_case.append(i['case_month'])
            current_case.append(i['res_state'])
            current_case.append(i['age_group'])
            current_case.append(i['sex'])
            current_case.append(i['icu_yn'])   
            total_cases.append(current_case)
    
    if len(fox)<50000:
        break

# %%
df = pd.DataFrame(total_cases, columns =['case_month', 'res_state', 'age_group','sex','icu_yn'])

# %%
df.head()
# Out:
#   case_month res_state     age_group sex   icu_yn
# 0    2021-08        OH  0 - 17 years  NA  Missing
# 1    2021-08        OH  0 - 17 years  NA  Missing
# 2    2021-08        OH  0 - 17 years  NA  Missing
# 3    2021-08        OH  0 - 17 years  NA  Missing
# 4    2021-08        OH  0 - 17 years  NA  Missing

# %%
len(df)
# Out:
# 1166645

# %%
import pandas as pd
from sodapy import Socrata

client = Socrata("data.cdc.gov", None)
#results = client.get("n8mc-b4w4.json?case_month=2021-08", limit=50000)#50000000
results = client.get("n8mc-b4w4", limit=5000000, case_month="2021-08")#50000000
original_data = pd.DataFrame.from_records(results)

# %time
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# CPU times: user 2 µs, sys: 7 µs, total: 9 µs
# Wall time: 13.1 µs

# %%
len(original_data)
# Out:
# 2946056

# %%
val = ast.literal_eval(mystr)
val1 = json.loads(json.dumps(val))
val2 = val1['tags'][0]['results'][0]['values']
print (pd.DataFrame(val2, columns=["time", "temperature

# %%
len(original_data[original_data["case_month"]=="2021-08"])
# Out:
# 48521

# %%
original_data.head()
# Out:
#   case_month res_state  state_fips_code  res_county  county_fips_code  \
# 0    2020-06        OH             39.0     BELMONT           39013.0
# 1    2020-09        OH             39.0      GALLIA           39053.0
# 2    2020-11        PA             42.0         ELK           42047.0
# 3    2021-02        AL              1.0  TALLAPOOSA            1123.0
# 4    2020-12        IA             19.0     CARROLL           19027.0
#
#         age_group     sex     race ethnicity  case_positive_specimen_interval  \
# 0             NaN     NaN      NaN       NaN                              0.0
# 1    0 - 17 years     NaN      NaN       NaN                              NaN
# 2  18 to 49 years     NaN      NaN       NaN                              0.0
# 3         Missing  Female  Missing   Missing                              NaN
# 4    0 - 17 years  Female      NaN       NaN                              NaN
#
#    case_onset_interval  process exposure_yn             current_status  \
# 0                  NaN  Missing     Missing  Laboratory-confirmed case
# 1                  NaN  Missing     Missing  Laboratory-confirmed case
# 2                  NaN  Missing     Missing  Laboratory-confirmed case
# 3                  NaN  Missing     Missing              Probable Case
# 4                  0.0  Missing     Missing              Probable Case
#
#   symptom_status  hosp_yn   icu_yn death_yn underlying_conditions_yn
# 0        Missing  Missing  Missing      NaN                      Yes
# 1        Missing  Missing  Missing       No                      NaN
# 2        Unknown       No  Unknown  Unknown                      NaN
# 3        Missing  Missing  Missing  Missing                      NaN
# 4    Symptomatic  Missing  Missing  Missing                      NaN

# %% [markdown]
# ### 2. Data preprocessing ###

# %% [markdown]
# #### 2.1 Age & Sex data ####

# %%
# Slice related columns
age_sex_data = original_data[["case_month", "age_group", "sex"]]
print("Original age, sex data size:",len(age_sex_data))

# Drop NA
age_sex_data = age_sex_data.dropna()
# Drop "Missing" and "Unknown" rows in age_group and sex
age_sex_data = age_sex_data[age_sex_data['age_group'] != "Missing"]
age_sex_data = age_sex_data[age_sex_data['age_group'] != "Unknown"]
age_sex_data = age_sex_data[age_sex_data['sex'] != "Missing"]
age_sex_data = age_sex_data[age_sex_data['sex'] != "Unknown"]
#age_sex_data = age_sex_data[age_sex_data['sex'] != "Other"]
print("After remove missing values:",len(age_sex_data))

age_sex_data.head()
# Out:
# Original age, sex data size: 50000
# After remove missing values: 49270
#   case_month       age_group sex
# 0    2020-11    0 - 17 years  NA
# 1    2021-03    0 - 17 years  NA
# 2    2020-08  18 to 49 years  NA
# 3    2021-07  18 to 49 years  NA
# 4    2020-07  18 to 49 years  NA

# %%
# Sorting data by case_month
age_sex_data = age_sex_data.sort_values('case_month')

age_sex_data.head()
# Out:
#       case_month       age_group     sex
# 12015    2020-03  18 to 49 years  Female
# 15352    2020-03  18 to 49 years  Female
# 18778    2020-03  18 to 49 years  Female
# 11685    2020-03  18 to 49 years    Male
# 12242    2020-03  18 to 49 years  Female

# %%
age_sex_data["sex_age"] = age_sex_data["sex"].astype(str) +"_"+ age_sex_data["age_group"].astype(str)
age_sex_data = age_sex_data[["case_month", "sex_age"]]

# %%
age_sex_data.head()
# Out:
#       case_month                sex_age
# 12015    2020-03  Female_18 to 49 years
# 15352    2020-03  Female_18 to 49 years
# 18778    2020-03  Female_18 to 49 years
# 11685    2020-03    Male_18 to 49 years
# 12242    2020-03  Female_18 to 49 years

# %%
age_sex_data_group_by = age_sex_data.groupby(['case_month', 'sex_age']).size().reset_index(name='counts')

# %%
age_sex_data_group_by
# Out:
#     case_month                sex_age  counts
# 0      2020-03  Female_18 to 49 years     173
# 1      2020-03  Female_50 to 64 years      12
# 2      2020-03       Female_65+ years      12
# 3      2020-03    Male_18 to 49 years      58
# 4      2020-03    Male_50 to 64 years      65
# ..         ...                    ...     ...
# 231    2021-09        NA_0 - 17 years      92
# 232    2021-09      NA_18 to 49 years      32
# 233    2021-09      NA_50 to 64 years      19
# 234    2021-09           NA_65+ years      40
# 235    2021-09                  NA_NA      37
#
# [236 rows x 3 columns]

# %%
# Convert dataframe to pivot table
age_sex_data_group_by = age_sex_data_group_by.pivot(index="case_month", columns="sex_age", values="counts")
# Replace NaN to 0
age_sex_data_group_by = age_sex_data_group_by.fillna(0)
# Convert float type to int
age_sex_data_group_by = age_sex_data_group_by.astype(int)
age_sex_data_group_by
# Out:
# sex_age     Female_0 - 17 years  Female_18 to 49 years  Female_50 to 64 years  \
# case_month
# 2020-03                       0                    173                     12
# 2020-04                      12                    484                     71
# 2020-05                      77                    585                    144
# 2020-06                     216                    786                     94
# 2020-07                     311                   1219                    204
# 2020-08                     160                   1081                    213
# 2020-09                     141                    732                     94
# 2020-10                     327                   1363                    187
# 2020-11                    1027                   2274                    669
# 2020-12                    1137                   1927                    541
# 2021-01                     923                   1721                    418
# 2021-02                     557                   1068                    190
# 2021-03                     402                    569                     90
# 2021-04                     508                    694                     55
# 2021-05                     199                    353                     65
# 2021-06                      33                    124                     11
# 2021-07                     315                    409                     23
# 2021-08                    1133                   1426                    248
# 2021-09                     486                    662                    115
#
# sex_age     Female_65+ years  Male_0 - 17 years  Male_18 to 49 years  \
# case_month
# 2020-03                   12                  0                   58
# 2020-04                   14                  0                  172
# 2020-05                   43                  9                  515
# 2020-06                   57                 42                  270
# 2020-07                   59                 14                  722
# 2020-08                   36                 72                  353
# 2020-09                   92                 79                  386
# 2020-10                  142                 66                  570
# 2020-11                  432                266                 1134
# 2020-12                  374                290                 1266
# 2021-01                  171                271                  996
# 2021-02                   84                160                  379
# 2021-03                  102                 82                  280
# 2021-04                   50                144                  254
# 2021-05                   34                125                  158
# 2021-06                    0                  0                   21
# 2021-07                   22                 73                  151
# 2021-08                  158                522                  608
# 2021-09                   53                134                  331
#
# sex_age     Male_50 to 64 years  Male_65+ years  NA_0 - 17 years  \
# case_month
# 2020-03                      65              12                0
# 2020-04                      12              67                0
# 2020-05                      99              15               13
# 2020-06                     120              12                8
# 2020-07                     172              12               20
# 2020-08                      54              12               70
# 2020-09                      88              48               52
# 2020-10                     193              11               52
# 2020-11                     420             184               82
# 2020-12                     364             138               84
# 2021-01                     218             143               98
# 2021-02                     157              31               98
# 2021-03                      53              29               79
# 2021-04                      88              26               73
# 2021-05                       4               0               38
# 2021-06                       0               0               25
# 2021-07                      59              34               85
# 2021-08                      81             145               59
# 2021-09                      62              61               92
#
# sex_age     NA_18 to 49 years  NA_50 to 64 years  NA_65+ years  NA_NA
# case_month
# 2020-03                    23                 26            10     16
# 2020-04                    30                 12            18     77
# 2020-05                    44                 12             8     34
# 2020-06                    60                 16             4     46
# 2020-07                    69                 18            10     32
# 2020-08                    85                 18            18     24
# 2020-09                    85                 58             7     59
# 2020-10                    69                 10            46     39
# 2020-11                   149                 35            46     66
# 2020-12                   198                 55            33     23
# 2021-01                   165                 26            24     60
# 2021-02                    41                 24            35     74
# 2021-03                    57                 55            17     33
# 2021-04                    33                 61             0     38
# 2021-05                    47                 16            15     26
# 2021-06                     4                 23            12      1
# 2021-07                    49                 11            33     18
# 2021-08                    84                 51            28     10
# 2021-09                    32                 19            40     37

# %%
# Drop Other gender since there's not enough data
#age_sex_data_group_by = age_sex_data_group_by.drop(['Other_18 to 49 years'], axis=1)

# %%
age_sex_data_group_by
# Out:
# sex_age     Female_0 - 17 years  Female_18 to 49 years  Female_50 to 64 years  \
# case_month
# 2020-03                       0                    173                     12
# 2020-04                      12                    484                     71
# 2020-05                      77                    585                    144
# 2020-06                     216                    786                     94
# 2020-07                     311                   1219                    204
# 2020-08                     160                   1081                    213
# 2020-09                     141                    732                     94
# 2020-10                     327                   1363                    187
# 2020-11                    1027                   2274                    669
# 2020-12                    1137                   1927                    541
# 2021-01                     923                   1721                    418
# 2021-02                     557                   1068                    190
# 2021-03                     402                    569                     90
# 2021-04                     508                    694                     55
# 2021-05                     199                    353                     65
# 2021-06                      33                    124                     11
# 2021-07                     315                    409                     23
# 2021-08                    1133                   1426                    248
# 2021-09                     486                    662                    115
#
# sex_age     Female_65+ years  Male_0 - 17 years  Male_18 to 49 years  \
# case_month
# 2020-03                   12                  0                   58
# 2020-04                   14                  0                  172
# 2020-05                   43                  9                  515
# 2020-06                   57                 42                  270
# 2020-07                   59                 14                  722
# 2020-08                   36                 72                  353
# 2020-09                   92                 79                  386
# 2020-10                  142                 66                  570
# 2020-11                  432                266                 1134
# 2020-12                  374                290                 1266
# 2021-01                  171                271                  996
# 2021-02                   84                160                  379
# 2021-03                  102                 82                  280
# 2021-04                   50                144                  254
# 2021-05                   34                125                  158
# 2021-06                    0                  0                   21
# 2021-07                   22                 73                  151
# 2021-08                  158                522                  608
# 2021-09                   53                134                  331
#
# sex_age     Male_50 to 64 years  Male_65+ years  NA_0 - 17 years  \
# case_month
# 2020-03                      65              12                0
# 2020-04                      12              67                0
# 2020-05                      99              15               13
# 2020-06                     120              12                8
# 2020-07                     172              12               20
# 2020-08                      54              12               70
# 2020-09                      88              48               52
# 2020-10                     193              11               52
# 2020-11                     420             184               82
# 2020-12                     364             138               84
# 2021-01                     218             143               98
# 2021-02                     157              31               98
# 2021-03                      53              29               79
# 2021-04                      88              26               73
# 2021-05                       4               0               38
# 2021-06                       0               0               25
# 2021-07                      59              34               85
# 2021-08                      81             145               59
# 2021-09                      62              61               92
#
# sex_age     NA_18 to 49 years  NA_50 to 64 years  NA_65+ years  NA_NA
# case_month
# 2020-03                    23                 26            10     16
# 2020-04                    30                 12            18     77
# 2020-05                    44                 12             8     34
# 2020-06                    60                 16             4     46
# 2020-07                    69                 18            10     32
# 2020-08                    85                 18            18     24
# 2020-09                    85                 58             7     59
# 2020-10                    69                 10            46     39
# 2020-11                   149                 35            46     66
# 2020-12                   198                 55            33     23
# 2021-01                   165                 26            24     60
# 2021-02                    41                 24            35     74
# 2021-03                    57                 55            17     33
# 2021-04                    33                 61             0     38
# 2021-05                    47                 16            15     26
# 2021-06                     4                 23            12      1
# 2021-07                    49                 11            33     18
# 2021-08                    84                 51            28     10
# 2021-09                    32                 19            40     37

# %%
age_sex_data_group_by.to_csv('age_sex_data_group_by.csv',index_label=age_sex_data_group_by.columns.name)

# %% [markdown]
# #### 2.2 Heavy symtom ####

# %%
# Slice related columns
heavy_symtom_data = original_data[["case_month", "icu_yn"]]
print("Original heavy symtom data size:",len(heavy_symtom_data))

# Drop NA
heavy_symtom_data = heavy_symtom_data.dropna()
# Drop "Missing" and "Unknown" rows in icu_yn column
heavy_symtom_data = heavy_symtom_data[heavy_symtom_data['icu_yn'] != "Missing"]
heavy_symtom_data = heavy_symtom_data[heavy_symtom_data['icu_yn'] != "Unknown"]
print("After remove missing values:",len(heavy_symtom_data))

# Sorting data by case_month
heavy_symtom_data = heavy_symtom_data.sort_values('case_month')

# Group by heavy symtom status
heavy_symtom_data_groupby = heavy_symtom_data.groupby(['case_month', 'icu_yn']).size().reset_index(name='counts')

# Convert dataframe to pivot table
heavy_symtom_data_groupby = heavy_symtom_data_groupby.pivot(index="case_month", columns="icu_yn", values="counts")

# Export dataframe to csv file
heavy_symtom_data_groupby.to_csv('heavy_symtom_data_groupby.csv',index_label=heavy_symtom_data_groupby.columns.name)
# Out:
# Original heavy symtom data size: 50000
# After remove missing values: 2832

# %% [markdown]
# #### 2.3 States ####

# %%
# Slice related columns
states_data = original_data[["case_month", "res_state"]]
print("Original states data size:",len(states_data))

# Drop NA
states_data = states_data.dropna()
# Drop "Missing" and "Unknown" rows in icu_yn column
states_data = states_data[states_data['res_state'] != "Missing"]
states_data = states_data[states_data['res_state'] != "Unknown"]
print("After remove missing values:",len(states_data))

# Sorting data by case_month
states_data = states_data.sort_values('case_month')

# Group by heavy symtom status
states_data_groupby = states_data.groupby(['case_month', 'res_state']).size().reset_index(name='counts')

# Convert dataframe to pivot table
states_data_groupby = states_data_groupby.pivot(index="case_month", columns="res_state", values="counts")

# Export dataframe to csv file
states_data_groupby.to_csv('states_data_groupby.csv',index_label=states_data_groupby.columns.name)
# Out:
# Original states data size: 50000
# After remove missing values: 50000

# %% [markdown]
# ### 3. Visualization ###

# %% [markdown]
# #### 3.1 Age sex data ####

# %%
age_sex_data = pd.read_csv("age_sex_data_group_by.csv")
age_sex_data = age_sex_data.rename({"sex_age":"Month"}, axis='columns')
age_sex_data = age_sex_data.set_index('Month')

plt.figure(figsize=(18,6))
plt.ticklabel_format(style='plain')
plt.xticks(rotation=45)
b = sns.lineplot(data=age_sex_data, sort=True, linewidth=1,
            palette="husl")

b.axes.set_title("Covid19",fontsize=20)
b.set_xlabel('Months', fontsize=15)
#b.set_ylabel("Covid cases",fontsize=15)

#plt.savefig('Covid.png')
# Out:
# Text(0.5, 0, 'Months')

# %% [markdown]
# #### 3.2 Heavy symtom data ####

# %%
heavy_symtom_data = pd.read_csv("heavy_symtom_data_groupby.csv")
heavy_symtom_data = heavy_symtom_data.rename({"icu_yn":"Month"}, axis='columns')
heavy_symtom_data = heavy_symtom_data.set_index('Month')

plt.figure(figsize=(18,6))
plt.ticklabel_format(style='plain')
plt.xticks(rotation=45)
b = sns.lineplot(data=heavy_symtom_data, sort=True, linewidth=1,
            palette="husl")
b.axes.set_title("Heavy symtom cases",fontsize=20)
b.set_xlabel('Months', fontsize=15)

#plt.savefig('Heavy_symtom.png')
# Out:
# Text(0.5, 0, 'Months')

# %%
heavy_symtom_data = pd.read_csv("heavy_symtom_data_groupby.csv")
heavy_symtom_data = heavy_symtom_data.rename({"icu_yn":"Month"}, axis='columns')
heavy_symtom_data = heavy_symtom_data.set_index('Month')

# Slice month index and patients status
months = heavy_symtom_data.index
heavy_symtom_data = heavy_symtom_data.reset_index(drop=True)
Heavy = heavy_symtom_data['Yes']
Not_Heavy = heavy_symtom_data['No']

# %%
fig, ax1 = plt.subplots(figsize=(18,9))

color = 'tab:green'
ax1.set_xlabel("Month")
ax1.set_ylabel("Normal symtom", color = color)
ax1 = sns.lineplot(x = months, y = Not_Heavy, sort=True, linewidth=3,
                  color = color)
paltte = 'summer'
ax1.tick_params(axis='y', color = color)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel("Heavy symtom", color = color)
ax2 = sns.lineplot(x = months, y = Heavy, sort=True, linewidth=1,
            color = color)
ax2.tick_params(axis='y', color = color)

plt.show()

# %% [markdown]
# done - change preprocessing step
# done - visualization (use two y axis for heavy symtom data)
# done - heavy symtom preprocessing

# %% [markdown]
# #### 3.3 States data ####

# %%
states_data = pd.read_csv("states_data_groupby.csv")
states_data = states_data.rename({"res_state":"Month"}, axis='columns')
states_data = states_data.set_index('Month')

states_data = states_data.fillna(0)
#states_data = states_data.astype(int)

states_data = states_data.T
states_data.iloc[2]
# Out:
# Month
# 2020-01        0.0
# 2020-02        0.0
# 2020-03     1057.0
# 2020-04     2573.0
# 2020-05     4711.0
# 2020-06    14480.0
# 2020-07    20900.0
# 2020-08    17437.0
# 2020-09    18803.0
# 2020-10    22654.0
# 2020-11    39392.0
# 2020-12    52464.0
# 2021-01    44109.0
# 2021-02    12479.0
# 2021-03     4473.0
# 2021-04     3658.0
# 2021-05     3655.0
# 2021-06     6144.0
# 2021-07    27400.0
# 2021-08      960.0
# Name: AR, dtype: float64

# %%
data = pd.read_csv("time_series_covid19_confirmed_global.csv")
data = data.groupby('Country/Region').sum()

data = data.drop(columns = ['Lat', "Long"])

# %%
data
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan               0        0        0        0        0        0
# Albania                   0        0        0        0        0        0
# Algeria                   0        0        0        0        0        0
# Andorra                   0        0        0        0        0        0
# Angola                    0        0        0        0        0        0
# ...                     ...      ...      ...      ...      ...      ...
# Vietnam                   0        2        2        2        2        2
# West Bank and Gaza        0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
#                     1/28/20  1/29/20  1/30/20  1/31/20  ...  8/29/21  8/30/21  \
# Country/Region                                          ...
# Afghanistan               0        0        0        0  ...   152960   153148
# Albania                   0        0        0        0  ...   144847   145333
# Algeria                   0        0        0        0  ...   195162   195574
# Andorra                   0        0        0        0  ...    15025    15032
# Angola                    0        0        0        0  ...    47168    47331
# ...                     ...      ...      ...      ...  ...      ...      ...
# Vietnam                   2        2        2        2  ...   435265   449489
# West Bank and Gaza        0        0        0        0  ...   337405   339816
# Yemen                     0        0        0        0  ...     7784     7829
# Zambia                    0        0        0        0  ...   206051   206145
# Zimbabwe                  0        0        0        0  ...   124437   124581
#
#                     8/31/21  9/1/21  9/2/21  9/3/21  9/4/21  9/5/21  9/6/21  \
# Country/Region
# Afghanistan          153220  153260  153306  153375  153375  153375  153534
# Albania              146387  147369  148222  149117  150101  150997  151499
# Algeria              196080  196527  196915  197308  197659  198004  198313
# Andorra               15033   15046   15052   15055   15055   15055   15069
# Angola                47544   47781   48004   48261   48475   48656   48790
# ...                     ...     ...     ...     ...     ...     ...     ...
# Vietnam              462096  473530  486727  501649  511170  524307  536788
# West Bank and Gaza   342282  344957  347730  350224  351809  353732  356474
# Yemen                  7869    7900    7951    8018    8056    8108    8142
# Zambia               206327  206522  206705  206884  207028  207114  207167
# Zimbabwe             124773  124960  125118  125331  125425  125550  125671
#
#                     9/7/21
# Country/Region
# Afghanistan         153626
# Albania             152239
# Algeria             198645
# Andorra              15070
# Angola               49114
# ...                    ...
# Vietnam             550996
# West Bank and Gaza  359236
# Yemen                 8181
# Zambia              207294
# Zimbabwe            125796
#
# [195 rows x 595 columns]

# %% [markdown]
# verify all process
#
# find a way to connect power BI and FLASK
